# %% [markdown]
# <a href="https://colab.research.google.com/github/yhamidah/AI-Assignments/blob/main/Chestnut_manju.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import matplotlib.pyplot as plt

CHESTNUT_DIAMETER_CM = 2.54
CHESTNUT_RADIUS_CM = CHESTNUT_DIAMETER_CM / 2
CHESTNUT_VOLUME_CM3 = (4/3) * math.pi * (CHESTNUT_RADIUS_CM ** 3)
CHESTNUT_VOLUME_M3 = CHESTNUT_VOLUME_CM3 * 1e-6

SOLAR_SYSYTEM_RADIUS_METERS = 4.545e9
SOLAR_SYSTEM_VOLUME_M3 = (4/3) * math.pi * (SOLAR_SYSYTEM_RADIUS_METERS ** 3)

volumes = []
minutes = []

def calculate_doubling_times(initial_volume, target_volume):
    doubling_times = 0
    while initial_volume < target_volume:
      initial_volume *= 2
      volumes.append(initial_volume)
      doubling_times += 5
      minutes.append(doubling_times)
    return doubling_times

time_to_fill_solar_system = calculate_doubling_times(CHESTNUT_VOLUME_M3,  SOLAR_SYSTEM_VOLUME_M3)

print(f"It will take {time_to_fill_solar_system} minutes to cover the solar system with the chestnut buns.")

plt.figure(figsize=(10, 6))
plt.plot(minutes, volumes)
plt.xlabel('Time (minutes)')
plt.ylabel('Volume (cubic meters)')
plt.title("Chestnut Bun Volume Increase Over Time")
plt.grid(True)
plt.show()
# Out:
# It will take 580 minutes to cover the solar system with the chestnut buns.

# %%
BALL_RADIUS_CM = 11
BALL_VOLUME_CM3 = (4/3) * math.pi * (BALL_RADIUS_CM ** 3)
BALL_VOLUME_M3 = BALL_VOLUME_CM3 * 1e-6

TOKYO_DOME_VOLUME_M3 = 1240000

print(f'it will take (time_to fill_solar_system) minutes to cover the tokyo dome with a ball.')
# Out:
# it will take (time_to fill_solar_system) minutes to cover the tokyo dome with a ball.
