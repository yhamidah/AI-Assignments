# %% [markdown]
# <a href="https://colab.research.google.com/github/yhamidah/AI-Assignments/blob/main/ASSIGNMENT1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PROBLEM ONE

# %%
THICKNESS = 0.00008
folded_thickness = THICKNESS * 2**43
print("Thickness: {} meteres" . format(folded_thickness))
# Out:
# Thickness: 703687441.77664 meteres

# %% [markdown]
# #PROBLEM TWO

# %%
print("Thickness: {: .2f} kilometers".format(folded_thickness / 1000))
# Out:
# Thickness:  703687.44 kilometers

# %% [markdown]
# #PROBLEM THREE

# %%
folded_thickness2 = THICKNESS
for i in range(1, 44):
   folded_thickness2 *= 2
print("Thickness: {} meters".format(folded_thickness2))
# Out:
# Thickness: 703687441.77664 meters

# %% [markdown]
# #PROBLEM FOUR

# %%
import time
start = time.time()
THICKNESS = 0.00008
folded_thickness = THICKNESS * 2**43
print("Thickness: {} meters" .format(folded_thickness2))
elasped_time = time.time() - start
print("time : {}[s]" .format(elasped_time))
# Out:
# Thickness: 703687441.77664 meters
# time : 0.0011382102966308594[s]

# %%
import time
start = time.time()
folded_thickness2 = THICKNESS
for i in range(1, 44):
   folded_thickness2 *= 2
print("Thickness: {} meters" .format(folded_thickness2))
elasped_time = time.time() - start
print("time : {}[s]".format(elasped_time))
# Out:
# Thickness: 703687441.77664 meters
# time : 0.0013153553009033203[s]

# %%
# %%timeit
THICKNESS = 0.00008
folded_thickness = THICKNESS * 2**43
print("Thickness: {} meters" .format(folded_thickness2))
# Out:
# Streaming output truncated to the last 5000 lines.
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# Thickness: 703687441.77664 meters
# ...

# %% [markdown]
# #PROBLEM FIVE

# %%
folded_thickness_list = []
folded_thickness2 = THICKNESS
for i in range(1, 44):
   folded_thickness2 *= 2
   folded_thickness_list.append(folded_thickness)

# %% [markdown]
# #PROBLEM SIX

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(folded_thickness_list)  # Enter the variable name of the list in "List name"
plt.show()

# %% [markdown]
# #PROBLEM SEVEN

# %%
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness[m]")
plt.plot(folded_thickness_list, color="red")
plt.show()
